# %%
import pandas as pd

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/9c/88/bc13c33fca11acaf808bd1809d8602d78f5bb84f7b1e7b1a288c383a14fd/mysql_connector_python-9.5.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB 682.7 kB/s eta 0:00:25
#    ---------------------------------------- 0.0/16.5 MB 2.0 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/16.5 MB 2.0 MB/s eta 0:00:09
#    ---------------------------------------- 0.2/16.5 MB 1.2 MB/s eta 0:00:14
#    - -------------------------------------- 0.6/16.5 MB 3.0 MB/s eta 0:00:06
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
host = 'localhost',
user = 'root',
password = 'root',
database = 'qa_analysis')

# %%
df=pd.read_sql('select * from quality_metrics', conn)
df
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_3744\1141569858.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql('select * from quality_metrics', conn)
#    project_id       framework    language  bug_count  lines_of_code  \
# 0      SE_001           React  TypeScript         89         125000
# 1      SE_002         FastAPI      Python         45          89000
# 2      SE_003     Spring_Boot        Java        156         234000
# 3      SE_004         Flutter        Dart         34          67000
# 4      SE_005  Apache_Airflow      Python         78         156000
# 5      SE_006           Unity          C#        234         345000
# 6      SE_007         PyTorch      Python         67         198000
# 7      SE_008         Laravel         PHP         89         123000
# ...

# %%
df.describe()
# Out:
#         bug_count  lines_of_code  bug_density  quality_score  debt_per_commit
# count   40.000000      40.000000    40.000000      40.000000        40.000000
# mean    99.675000  163850.000000     0.588250      59.955000         0.077250
# std     63.696149   91155.699429     0.099328       9.966447         0.026601
# min     23.000000   45000.000000     0.340000      38.160000         0.030000
# 25%     56.000000   89000.000000     0.510000      53.405000         0.060000
# 50%     89.000000  139500.000000     0.615000      61.415000         0.070000
# 75%    128.500000  207000.000000     0.660000      67.447500         0.082500
# max    289.000000  456000.000000     0.810000      80.320000         0.160000

# %%
df.corr(numeric_only = True)
# Out:
#                  bug_count  lines_of_code  bug_density  quality_score  \
# bug_count         1.000000       0.972561     0.564050      -0.696113
# lines_of_code     0.972561       1.000000     0.379616      -0.603339
# bug_density       0.564050       0.379616     1.000000      -0.622103
# quality_score    -0.696113      -0.603339    -0.622103       1.000000
# debt_per_commit   0.627168       0.521347     0.648314      -0.735201
#
#                  debt_per_commit
# bug_count               0.627168
# lines_of_code           0.521347
# bug_density             0.648314
# quality_score          -0.735201
# debt_per_commit         1.000000
